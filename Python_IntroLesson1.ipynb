# %%
print("Hello Emade Consulting Developers")
# Out:
# Hello Emade Consulting Developers

# %%
#variables
Jerry = "Hello Emade Developers"
print(Jerry)
# Out:
# Hello Emade Developers

# %%
Jerry
# Out:
# 'Hello Emade Developers'

# %%
print("Jerry")
# Out:
# Jerry

# %%
print(Jerry.upper())
# Out:
# HELLO EMADE DEVELOPERS

# %%
print(Jerry.lower())
# Out:
# hello emade developers

# %%
#variables
firstName = "Jeremiah"
lastName = "Osim"
fullName = firstName + " " + lastName
print(fullName)
# Out:
# Jeremiah Osim

# %%
# add a new line 
print("languages:\n\tpython\n\tjava\n\tgo")
# Out:
# languages:
# 	python
# 	java
# 	go

# %%
# add  a new line to name
print(fullName:\n\tfirstName\n\tlastName)
# Out:
#   Cell In[12], line 2
#     print(fullName:\n\tfirstName\n\tlastName)
#                   ^
# SyntaxError: invalid syntax

# %%
# add a new line to name
print("fullName:\n\tfirstName\n\tlastName")
# Out:
# fullName:
# 	firstName
# 	lastName

# %%
# Define the name variables
firstName = "Jeremiah"  # Replace with your actual firstName variable
lastName = "Osim"    # Replace with your actual lastName variable
fullName = f"{firstName} {lastName}"

# Print the names with proper formatting
print(f"fullName:\n\t{firstName}\n\t{lastName}")
# Out:
# fullName:
# 	Jeremiah
# 	Osim

# %%
# Data Type:
# Numbers
2+3
# Out:
# 5

# %%
5+8
# Out:
# 13

# %%
(2+3)*4
# Out:
# 20

# %%
3**2
# Out:
# 9

# %%
3**4
# Out:
# 81

# %%
# float --it's like a decimal
0.1 + 0.1
# Out:
# 0.2

# %%
2*0.2
# Out:
# 0.4

# %%
# age --concatenate (join) string and integer
age = 83
message = "happy" + age + "rd birthday, prof!"
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # age --concatenate (join) string and integer
#       2 age = 83
# ----> 3 message = "happy" + age + "rd birthday, prof!"
#       4 print(message)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# age --concatenate (join) string and integer
age = 83
message = "happy " + str(age) + "rd birthday, prof!"
print(message)
# Out:
# happy 83rd birthday, prof!

# %%
print(message.upper())
# Out:
# HAPPY 83RD BIRTHDAY, PROF!
